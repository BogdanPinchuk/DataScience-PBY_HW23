# %% [markdown]
# # 📘 Домашнє завдання №23. Основи LLM
#
# Виконав: **Bohdan Pinchuk**
#
# Link: https://github.com/BogdanPinchuk/DataScience-PBY_HW23

# %% [markdown]
# # 🧩 Завдання 1 — Робота з HuggingFace (обов’язкове)
#
# 1. Встановіть бібліотеку `transformers`
# 2. Завантажте будь-яку модель через `pipeline` для   sentiment-analysis
# 3. Зробіть 3 різні запити:
#    - позитивний текст
#    - негативний текст
#    - нейтральний текст
#
# ### 📌 Результат:
# - вивід результатів моделі
# - короткий висновок (2–3 речення): чи правильно модель все класифікує
#
# ---
#
# # ✍️ Завдання 2 — Генерація тексту
#
# Використайте модель для генерації тексту.
#
# 1. Створіть prompt (будь-який):
#    - про AI
#    - про навчання
#    - про майбутнє технологій
#
# 2. Зміні параметри:
#    - `temperature = 0.2`
#    - `temperature = 0.8`
#    - `temperature = 1.2`
#
# ### 📌 Результат:
# - 3 різні відповіді
# - пояснення: як змінюється стиль тексту
#
# ---
#
# # 🧠 Завдання 3 — Prompt Engineering
#
# Створіть 3 варіанти prompt для однієї задачі:
#
# ### Задача:
# > Класифікація настрою тексту
#
# ### Варіанти:
# 1. Zero-shot prompt
# 2. Few-shot prompt (з 2 прикладами)
# 3. Role prompt (наприклад: “You are an AI assistant...”)
#
# ### 📌 Результат:
# - 3 промпти
# - результати моделі
# - який варіант працює найкраще і чому
#
# ---
#
# # 🔎 Завдання 4 — Ембеддінги
#
# 1. Візьміть 4–6 текстів (наприклад, фрази про технології)
# 2. Побудуйте embeddings (можна через `sentence-transformers`)
# 3. Порахуйте cosine similarity
# 4. Знайдіть:
#    - найбільш схожі пари текстів
#
# ### 📌 Результат:
# - матриця схожості
# - 2–3 висновки

# %%
# # Silent installation or update
#
# # Clean cache
# !python3 -m pip cache purge -q
#
# # Force updating
# package_update = [
#     "pip",
#     "scikit-learn",
#     "pandas",
#     "kagglehub",
#     "kagglesdk",
# ]
#
# for package_name in package_update:
#     !bash -c "python3 -m pip install -U '{package_name}' -q"
#
# # Install missing packages
# package_array = [
#     "jinja2",
#     "ipywidgets",
#     "nbformat",
#     "kagglehub[pandas-datasets]",
#     "numpy",
#     "matplotlib",
#     "scipy",
#     "statsmodels",
#     "joblib",
#     "torch",
#     "transformers",
#     "sentence_transformers",
# ]
#
# for package_name in package_array:
#     !bash -c "python3 -m pip show '{package_name}' > /dev/null 2>&1 || python3 -m pip install -U '{package_name}' -q"

# Note. To upload big files to GitHub, execute the next command in the terminal
# 1. brew install git-lfs
# 2. git lfs install
# 3.1. git lfs track "*.safetensors"
# 3.2. git lfs track "*.bin"

# %%
# # Synchronization with remote source
#
# import shutil
# from pathlib import Path
#
# # Input data
hm_version = 23
#
# # Solution
# git_project_url = f"https://github.com/BogdanPinchuk/DataScience-PBY_HW{hm_version}.git"
# main_file_name = f"Bohdan_Pinchuk_DS_HW{hm_version}.ipynb"
#
# # upload all files
# current_path = !pwd
# current_path = current_path[0]
# parent_path = !dirname "$current_path"
# parent_path = parent_path[0]
# temp_path = f"{parent_path}/temp"
#
# # Clone data
# !rm -rf "$temp_path"
# !git clone "$git_project_url" "$temp_path"
#
# source = Path(temp_path)
# destination = Path(current_path)
# exclude = {main_file_name, ".git", ".idea"}
#
# for item in source.iterdir():
#     if item.name in exclude:
#         continue
#
#     target = destination / item.name
#     if item.is_dir():
#         shutil.copytree(item, target, dirs_exist_ok=True)
#     else:
#         shutil.copy2(item, target)
#
# # Clean temp folder
# !rm -rf "$temp_path"

# %% [markdown]
# # ✅ Рішення: 1 — Робота з HuggingFace (обов’язкове)
#
# 1. Встановіть бібліотеку `transformers`
# 2. Завантажте будь-яку модель через `pipeline` для   sentiment-analysis
# 3. Зробіть 3 різні запити:
#    - позитивний текст
#    - негативний текст
#    - нейтральний текст
#
# Результат:
# - вивід результатів моделі
# - короткий висновок (2–3 речення): чи правильно модель усе класифікує

# %%
# Classifier

import torch
import apps.reporter as rpt
from pathlib import Path
from transformers import pipeline

# Input data
load_model = True
model_file_name = "resources/sentiment_model"
input_texts = [
    "Цей курс Data Science просто неперевершений, він надає корисні фундаментальні знання!",
    "Найгірші компанії — це ті, які з року в рік підіймають ціни, але не дають ніяких інновацій, тому їх крах неминучий.",
    "Напрямок Data Science прогнозовано розвивається з року в рік.",
    "Технічні науки - дуже цікава сфера знань.",
    "Через стрічки в соцмережах ми сильно деградуємо й марно витрачаємо свій час.",
]

# Solution
file_path = Path(model_file_name)

# try to load model
if load_model and file_path.exists():
    sentiment_model = pipeline(
        "text-classification",
        model=model_file_name,
        tokenizer=model_file_name
    )
else:
    sentiment_model = pipeline(
        "text-classification",
        model="tabularisai/multilingual-sentiment-analysis"
    )
    # save model
    sentiment_model.model.save_pretrained(model_file_name)
    sentiment_model.tokenizer.save_pretrained(model_file_name)

rp = rpt.Reporter("Запис", "Оцінка")
rp.tolerance = 4

for text in input_texts:
    response = sentiment_model(text)[0]
    rp.add_item(text, f"Label: {response["label"]}, Score: {rp.format_value(response["score"])}")

# Print results
rp.print_pd_report("Результати моделі")
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# <style type="text/css">
# #T_c9822 th {
#   text-align: left;
# }
# #T_c9822_row0_col0, #T_c9822_row0_col1, #T_c9822_row1_col0, #T_c9822_row1_col1, #T_c9822_row2_col0, #T_c9822_row2_col1, #T_c9822_row3_col0, #T_c9822_row3_col1, #T_c9822_row4_col0, #T_c9822_row4_col1 {
#   text-align: left;
#   white-space: pre-wrap;
#   border: 1px solid lightgrey;
# }
# </style>
# <table id="T_c9822">
#   <caption>Результати моделі</caption>
#   <thead>
#     <tr>
#       <th id="T_c9822_level0_col0" class="col_heading level0 col0" >Запис</th>
#       <th id="T_c9822_level0_col1" class="col_heading level0 col1" >Оцінка</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c9822_row0_col0" class="data row0 col0" >Цей курс Data Science просто неперевершений, він надає корисні фундаментальні знання!</td>
#       <td id="T_c9822_row0_col1" class="data row0 col1" >Label: Very Positive, Score: 0.5590</td>
#     </tr>
#     <tr>
#       <td id="T_c9822_row1_col0" class="data row1 col0" >Найгірші компанії — це ті, які з року в рік підіймають ціни, але не дають ніяких інновацій, тому їх крах неминучий.</td>
#       <td id="T_c9822_row1_col1" class="data row1 col1" >Label: Very Negative, Score: 0.8883</td>
#     </tr>
#     <tr>
#       <td id="T_c9822_row2_col0" class="data row2 col0" >Напрямок Data Science прогнозовано розвивається з року в рік.</td>
#       <td id="T_c9822_row2_col1" class="data row2 col1" >Label: Neutral, Score: 0.9368</td>
#     </tr>
#     <tr>
#       <td id="T_c9822_row3_col0" class="data row3 col0" >Технічні науки - дуже цікава сфера знань.</td>
#       <td id="T_c9822_row3_col1" class="data row3 col1" >Label: Positive, Score: 0.8129</td>
#     </tr>
#     <tr>
#       <td id="T_c9822_row4_col0" class="data row4 col0" >Через стрічки в соцмережах ми сильно деградуємо й марно витрачаємо свій час.</td>
#       <td id="T_c9822_row4_col1" class="data row4 col1" >Label: Negative, Score: 0.7777</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Висновок. Для роботи з українською мовою була використана багатокласова мультимовна модель, яка чудово все покласифікувала. Але вона не достатньо хороша, і інколи без більшого контексту негативні результати бачить як позитивні.

# %% [markdown]
# # ✅ Рішення: 2 — Генерація тексту
#
# Використайте модель для генерації тексту.
#
# 1. Створіть prompt (будь-який):
#    - про AI
#    - про навчання
#    - про майбутнє технологій
#
# 2. Зміні параметри:
#    - `temperature = 0.2`
#    - `temperature = 0.8`
#    - `temperature = 1.2`
#
# Результат:
# - 3 різні відповіді
# - пояснення: як змінюється стиль тексту

# %%
# Text Generation

import torch
import apps.reporter as rpt
from pathlib import Path
from transformers import pipeline, GenerationConfig

# Input data
load_model = True
model_file_name = "resources/text_generation_model"
temperatures = [0.2, 0.8, 1.2]
prompt = "У майбутньому генеративний штучний інтелект буде"

# Solution
file_path = Path(model_file_name)

# try to load model
if load_model and file_path.exists():
    generator = pipeline(
        "text-generation",
        model=model_file_name,
        tokenizer=model_file_name,
        clean_up_tokenization_spaces=False,
    )
else:
    generator = pipeline(
        "text-generation",
        model="benjamin/gpt2-wechsel-ukrainian",
        # model="malteos/gpt2-uk",
        clean_up_tokenization_spaces=False,
    )
    # save model
    generator.model.save_pretrained(model_file_name)
    generator.tokenizer.save_pretrained(model_file_name)

rp = rpt.Reporter("Коефіцієнт креативності", "Відповідь")

for temperature in temperatures:
    config = GenerationConfig(
        max_new_tokens=50,
        temperature=temperature,
        num_return_sequences=1,
        do_sample=True,  # випадковий вибір слів
        top_p=0.9,  # уникаємо малоймовірних слів
        no_repeat_ngram_size=3,  # уникаємо зациклювання
        pad_token_id=generator.tokenizer.eos_token_id,
    )
    response = generator(prompt, generation_config=config)[0]["generated_text"]
    rp.add_item(str(temperature), response)

# Print results
rp.print_pd_report("Результати моделі")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# <style type="text/css">
# #T_5ee35 th {
#   text-align: left;
# }
# #T_5ee35_row0_col0, #T_5ee35_row0_col1, #T_5ee35_row1_col0, #T_5ee35_row1_col1, #T_5ee35_row2_col0, #T_5ee35_row2_col1 {
#   text-align: left;
#   white-space: pre-wrap;
#   border: 1px solid lightgrey;
# }
# </style>
# <table id="T_5ee35">
#   <caption>Результати моделі</caption>
#   <thead>
#     <tr>
#       <th id="T_5ee35_level0_col0" class="col_heading level0 col0" >Коефіцієнт креативності</th>
#       <th id="T_5ee35_level0_col1" class="col_heading level0 col1" >Відповідь</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5ee35_row0_col0" class="data row0 col0" >0.2</td>
#       <td id="T_5ee35_row0_col1" class="data row0 col1" >У майбутньому генеративний штучний інтелект буде використовуватися для управління транспортними засобами.
# У майбутньому штучний інтелект стане частиною системи управління дорожнім рухом, яка буде використовуватися в якості системи контролю за дорожнім покриттям.
# В даний час в світі налічується близько 500 тисяч автомобілів, які управляються штучним інтелектом.</td>
#     </tr>
#     <tr>
#       <td id="T_5ee35_row1_col0" class="data row1 col0" >0.8</td>
#       <td id="T_5ee35_row1_col1" class="data row1 col1" >У майбутньому генеративний штучний інтелект буде використовувати дані і знання, отримані від інших людей, щоб поліпшити якість життя людей.
# За словами представників компанії, за допомогою штучного інтелекту можна поліпшити рівень життя людей на різних рівнях.
# «Ми хочемо, щоб люди могли бути щасливими. Якщо ми зможемо допомогти</td>
#     </tr>
#     <tr>
#       <td id="T_5ee35_row2_col0" class="data row2 col0" >1.2</td>
#       <td id="T_5ee35_row2_col1" class="data row2 col1" >У майбутньому генеративний штучний інтелект буде розвиватися як технологія для контролю і запобігання помилок фермерів. До того ж, за інформацією компанії-розробника, технологія зможе визначати не тільки стан полів, але і ступінь ризику для здоров'я населення. На даний момент компанія не збирається зупинятися на досягнутому,</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Висновок. Зі збільшенням коефіцієнта креативності модель робить менше повторень і генерує більш різноманітний текст, проте його зміст стає менш логічним та зв'язним.

# %% [markdown]
# # ✅ Рішення: 3 — Prompt Engineering
#
# Створіть 3 варіанти prompt для однієї задачі:
#
# Задача:
# > Класифікація настрою тексту
#
# Варіанти:
# 1. Zero-shot prompt
# 2. Few-shot prompt (з 2 прикладами)
# 3. Role prompt (наприклад: “You are an AI assistant...”)
#
# Результат:
# - 3 промпти
# - результати моделі
# - який варіант працює найкраще і чому

# %%
# Prompt Engineering

import torch
import apps.reporter as rpt
from transformers import pipeline, GenerationConfig

# Input data
load_model = True
model_file_name = "resources/instruction_understanding_model"

prompts = {
    "Zero-shot": """
    Класифікуй настрій.
    Поверни ТІЛЬКИ одне слово: "Позитивний" або "Негативний".
    Текст для аналізу: Сервіс має баги.
    Настрій:
    """,
    "Few-shot": """
    Класифікуй настрій.
    Текст: "Цей метод хороший"
    Настрій: Позитивний
    Текст: Цей код поганий.
    Настрій: Негативний
    Текст для аналізу: Сервіс має баги.
    Настрій:
    """,
    "Role prompt": """
    Ви помічник зі штучним інтелектом.
    Поясни, що таке Data Science, простими словами для новачка:
    Відповідь:
    """
}

# Solution
file_path = Path(model_file_name)

# try to load model
if load_model and file_path.exists():
    generator = pipeline(
        "text-generation",
        model=model_file_name,
        tokenizer=model_file_name,
        clean_up_tokenization_spaces=False,
    )
else:
    generator = pipeline(
        "text-generation",
        model="Qwen/Qwen2.5-0.5B-Instruct",
        # model="Qwen/Qwen2.5-1.5B-Instruct",
        clean_up_tokenization_spaces=False,
    )
    # save model
    generator.model.save_pretrained(model_file_name)
    generator.tokenizer.save_pretrained(model_file_name)

rp = rpt.Reporter("Промпт для моделі", "Відповідь")

for prompt_name, prompt in prompts.items():
    if prompt_name == "Role prompt":
        max_new_tokens = 55
    else:
        max_new_tokens = 10

    config = GenerationConfig(
        max_new_tokens=max_new_tokens,
        temperature=0.3,
        do_sample=False,
        no_repeat_ngram_size=3,
        pad_token_id=generator.tokenizer.eos_token_id,
    )
    response = generator(prompt, generation_config=config)[0]["generated_text"][len(prompt):].strip()
    rp.add_item(f"{prompt_name}\n{prompt}", response)

# Print results
rp.print_pd_report("Результати моделі")
# Out:
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# <style type="text/css">
# #T_87efd th {
#   text-align: left;
# }
# #T_87efd_row0_col0, #T_87efd_row0_col1, #T_87efd_row1_col0, #T_87efd_row1_col1, #T_87efd_row2_col0, #T_87efd_row2_col1 {
#   text-align: left;
#   white-space: pre-wrap;
#   border: 1px solid lightgrey;
# }
# </style>
# <table id="T_87efd">
#   <caption>Результати моделі</caption>
#   <thead>
#     <tr>
#       <th id="T_87efd_level0_col0" class="col_heading level0 col0" >Промпт для моделі</th>
#       <th id="T_87efd_level0_col1" class="col_heading level0 col1" >Відповідь</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_87efd_row0_col0" class="data row0 col0" >Zero-shot
#
#     Класифікуй настрій.
#     Поверни ТІЛЬКИ одне слово: "Позитивний" або "Негативний".
#     Текст для аналізу: Сервіс має баги.
#     Настрій:
#     </td>
#       <td id="T_87efd_row0_col1" class="data row0 col1" >- "Постійний"
#      -</td>
#     </tr>
#     <tr>
#       <td id="T_87efd_row1_col0" class="data row1 col0" >Few-shot
#
#     Класифікуй настрій.
#     Текст: "Цей метод хороший"
#     Настрій: Позитивний
#     Текст: Цей код поганий.
#     Настрій: Негативний
#     Текст для аналізу: Сервіс має баги.
#     Настрій:
#     </td>
#       <td id="T_87efd_row1_col1" class="data row1 col1" >- Нега-позитивні</td>
#     </tr>
#     <tr>
#       <td id="T_87efd_row2_col0" class="data row2 col0" >Role prompt
#
#     Ви помічник зі штучним інтелектом.
#     Поясни, що таке Data Science, простими словами для новачка:
#     Відповідь:
#     </td>
#       <td id="T_87efd_row2_col1" class="data row2 col1" >- Data Science - це використання аналізування та обчислювання з даних, які можуть бути вартою для розв'язання проблем.
#       Ц</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Висновок. Ця мультимовна модель показала себе доволі погано, лише в Role prompt вона спробувала зробити пояснення. Але причиною є те, що через обмеження памʼяті, обрана модель займає менше місця, а отже й має гірше навчання. У випадку вибору більш потужнішої моделі, результати були б набагато кращі, але при цьому й обчислювальних ресурсів треба буде більше.

# %% [markdown]
# # ✅ Рішення: 4 — Ембеддінги
#
# 1. Візьміть 4–6 текстів (наприклад, фрази про технології)
# 2. Побудуйте embeddings (можна через `sentence-transformers`)
# 3. Порахуйте cosine similarity
# 4. Знайдіть:
#    - найбільш схожі пари текстів
#
# Результат:
# - матриця схожості
# - 2–3 висновки

# %%
# Embeddings and Sentence Matching

import torch
from transformers import pipeline, GenerationConfig
from sentence_transformers import SentenceTransformer

# Input data
load_model = True
model_file_name = "resources/embedding_model"

sentences = {
    0: "",
}

# Solution
file_path = Path(model_file_name)

# try to load model
if load_model and file_path.exists():
    model = SentenceTransformer(model_file_name)
else:
    model =  SentenceTransformer('sentence-transformers/LaBSE')
    # save model
    model.save(model_file_name)

# rp = rpt.Reporter("Промпт для моделі", "Відповідь")
#
# for prompt_name, prompt in prompts.items():
#     if prompt_name == "Role prompt":
#         max_new_tokens = 55
#     else:
#         max_new_tokens = 10
#
#     config = GenerationConfig(
#         max_new_tokens=max_new_tokens,
#         temperature=0.3,
#         do_sample=False,
#         no_repeat_ngram_size=3,
#         pad_token_id=generator.tokenizer.eos_token_id,
#     )
#     response = generator(prompt, generation_config=config)[0]["generated_text"][len(prompt):].strip()
#     rp.add_item(f"{prompt_name}\n{prompt}", response)
#
# # Print results
# rp.print_pd_report("Результати моделі")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
